# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import sys
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import os


sys.path.append("/Users/sylvainbertaina/Documents/__Labo/Python Scripts/EPRfunctions")
import BrukerConverter  as conv
import EPRplot2 as EPR
import  glob 
import fnmatch
import re
from os.path import splitext,getmtime
from IPython.display import Markdown as md
PATH="/Users/sylvainbertaina/Documents/__Labo/Python Scripts/EPRfunctions/"
#PATH='/Users/sylvainbertaina/Documents/__Labo/DATA/DMTTF/DMTTF_X_HYSCORE/DMTTF2_Br_HYSCORE/all_DSC_files/'


mpl.style.use('default')
mpl.rcParams['figure.dpi'] = 200
mpl.rcParams["lines.linewidth"]=.5

filefolder=conv.BrukerListFile(PATH)

# %%
for file in filefolder:
    data=conv.readEPR(file)
    try :
        x,y,par=data
        EPR.plot1D(x,y,par)
        plt.show()
        
    except ValueError:
        x,y,z,par=data
        EPR.plot2D(x,y,z,par)
        plt.show()
    except ValueError:
        print('error in')
# Out:
# elixis file
# 1D
# elixis file
# 1D
# EMX file
# 2D
# EMX file
# 1D
# elixis file
# 2D

# %%
x,y,z,par=conv.readEPR(filefolder[4])
# Out:
# elixis file
# 2D

# %%
EPR.plot2D(x,y,z,par,blCorrection=True)

# %%
EPR.plotFFT2D(x,z,par)
plt.gca()
plt.ylim(0,30)
# Out:
# (0.0, 30.0)

# %%
plt.plot(x,c)
plt.show()

# %%
a,b=conv.generate_dataElixys(filefolder[1])
