# %%
# %reload_ext autoreload
# %autoreload 2

EPRTools_dir="/Users/sylvainbertaina/Documents/Cloud_CNRS/GitHub"

import os
import sys
if EPRTools_dir not in sys.path:
    sys.path.append(EPRTools_dir)

# %%
#import sys
#sys.path.append("/Users/sylvainbertaina/Documents/__Labo/Python Scripts")

from scipy.optimize import curve_fit
import math
from scipy.optimize import fsolve
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt
import numpy as np

import EPyRTools as epr


import matplotlib.cm as cm
import matplotlib as mpl

from cycler import cycler

mpl.style.use('default')

PATHdata='./data/'
PATHfig='./fig/'
fwidth=3.54
fwidth2c=7.05687

# %%
[x,y,par,fn]=epr.eprload("./Tutorials/2014_03_19_MgO_300K_111_fullrotation33dB.par",plot_if_possible=True)
y
# Out:
# w
# Plotting 2D data (real part) using pcolormesh.
# array([[-28.127441  , -16.127441  ,   3.8725586 , ...,  19.872559  ,
#         -15.127441  ,   4.8725586 ],
#        [ 23.57959   ,  44.57959   ,  -6.42041   , ...,   7.57959   ,
#         -14.42041   ,  15.57959   ],
#        [ 26.666992  , -44.333008  ,   4.666992  , ...,  14.666992  ,
#           2.6669922 , -29.333008  ],
#        ...,
#        [  9.581543  ,  -7.418457  ,  13.581543  , ..., -34.418457  ,
#         -39.418457  , -41.418457  ],
#        [-16.844238  , -17.844238  ,  -4.8442383 , ...,  34.15576   ,
#         -12.844238  ,  -2.8442383 ],
#        [ 21.189453  ,  19.189453  ,  -4.810547  , ..., -18.810547  ,
#         -15.810547  ,   0.18945312]], shape=(37, 2048), dtype=float32)

# %%
[x,y,par,fn]=epr.eprload("/Users/sylvainbertaina/Documents/__Labo/_AchutanThesis/Data/Yb171_Sample/Pulsed/MD5_Cavity/Grenoble_Mar_2025/Achuthan/2025_05_171Yb_ATCW20ppm_EFS_6K_12dB_1400_3400.DTA",plot_if_possible=True)

# %%
[x,y,par,fn]=epr.eprload("/Users/sylvainbertaina/Documents/Cloud_IM2NP/EPR_EMX/Jalila/LPMO/2023_04/20230407_LPMO_Melange_11p5_10K_26dB.par",plot_if_possible=True)
# Out:
# w

# %%
[x,y,par,fn]=epr.eprload("/Users/sylvainbertaina/Documents/__Labo/_AchutanThesis/Data/Yb171_Sample/Pulsed/MD5_Cavity/Grenoble_Mar_2025/Achuthan/2025_05_171Yb_ATCW20ppm_T2_5K_12dB_6561G_Ortho_16_32_bis.DSC",plot_if_possible=True)

# %%
plt.plot(x,np.sqrt((y.real-1e5)**2+(y.imag-1e5)**2))

# %%
fig,ax = epr.plot_angular_sweep_waterfall(x[0],x[1],y)
ax.set_title("SS17 , T=10K, Angular sweep, single crystal")
# Out:
# Text(0.5, 1.0, 'SS17 , T=10K, Angular sweep, single crystal')

# %%
par.get('XNAM','XUNI')
# Out:
# 'Field'

# %%
x
# Out:
# array([0.00000000e+00, 2.19833903e+00, 4.39667807e+00, ...,
#        4.49560332e+03, 4.49780166e+03, 4.50000000e+03], shape=(2048,))

# %%
y
# Out:
# array([ 1091625984,  1091625984,  1091625984, ..., -1065353216,
#        -1065353216,           0], shape=(2048,), dtype=int32)

# %%
plt.plot(x,y)

# %%
y
# Out:
# array([236726.+127220.j, 240217.+129483.j, 253076.+150147.j, ...,
#         94476.+107215.j,  91591.+102272.j,  85676. +90058.j],
#       shape=(1024,))

# %%
isinstance(par,list)
# Out:
# False

# %%
par.get('XXUN')
# Out:
# 'G'

# %%
par
# Out:
# {'DOS': 'Format',
#  'ANZ': 75776,
#  'MIN': -20505.589844,
#  'MAX': 24769.074219,
#  'JSS': 4096,
#  'SSX': 2048,
#  'SSY': 37,
#  'XXLB': 3000.0,
#  'XXWI': 700.0,
#  'XYLB': 0.0,
#  'XYWI': 180.0,
#  'XXUN': 'G',
#  'XYUN': 'deg',
#  'JON': 'Bruker BioSpin GmbH',
#  'JDA': '19-Mar-2014',
#  'JTM': '11:09',
#  'JRE': 'c:\\program files\\bruker emx\\syscal_old\\emx1240\\er4102st\\4102st130710.cal',
#  'JEX': 'field-sweep',
#  'JEY': 'angle-sweep',
#  'RES': 2048,
#  'REY': 37,
#  'JSD': 1,
#  'HCF': 3350.0,
#  'HSW': 700.0,
#  'RCT': 20.48,
#  'RTC': 10.24,
#  'RRG': 31697.86,
#  'RMA': 1.0,
#  'MF': 9.399263,
#  'MP': 0.1001,
#  'MPD': 33.0,
#  'GAN': 0.0,
#  'GANS': 5.0,
#  'XAXIS_NAME': 'field-sweep',
#  'XAXIS_UNIT': 'G'}
